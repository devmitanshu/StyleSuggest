# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1352f043-1b3b-41b3-a725-d4c54ba2457c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1352f043-1b3b-41b3-a725-d4c54ba2457c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
import seaborn as sns

#Load the data
df = pd.read_excel('Data set Hackathon Products Customer Images Myntra.xlsx')

#View the data
df.head(3)
# Out:
#    Gender      Category Sub-Category Site_Name  \
# 0  Female  Western Wear      Dresses    Myntra
# 1  Female  Western Wear      Dresses    Myntra
# 2  Female  Western Wear      Dresses    Myntra
#
#                                          Product_URL Brand_Name  \
# 0  https://www.myntra.com/dresses/antheaa/antheaa...    Antheaa
# 1  https://www.myntra.com/dresses/berrylush/berry...  Berrylush
# 2  https://www.myntra.com/dresses/athena/athena-l...     Athena
#
#                                       Product_name Price  \
# 0  Fuchsia Solid Chiffon Smocked Tiered Midi Dress  1007
# 1         Women Classic White Floral Bustier Dress   881
# 2       Lavender Solid Accordion Pleats Wrap Dress  1203
#
#                                           Image_URLs  Ratings  ...  \
# 0  https://assets.myntassets.com/h_720,q_90,w_540...      4.2  ...
# 1  https://assets.myntassets.com/h_720,q_90,w_540...      4.0  ...
# 2  https://assets.myntassets.com/h_720,q_90,w_540...      4.2  ...
#
# ...

# %%
df.Fit.isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1248     True
# 1249    False
# 1250    False
# 1251    False
# 1252    False
# Name: Fit, Length: 1253, dtype: bool

# %%
df.shape
# Out:
# (1253, 21)

# %%
df.isnull().sum().sum()
# Out:
# 3148

# %%
#Basic information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1253 entries, 0 to 1252
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Gender               1253 non-null   object
#  1   Category             1253 non-null   object
#  2   Sub-Category         1253 non-null   object
#  3   Site_Name            1253 non-null   object
#  4   Product_URL          1253 non-null   object
#  5   Brand_Name           1253 non-null   object
#  6   Product_name         1253 non-null   object
#  7   Price                1253 non-null   object
#  8   Image_URLs           1253 non-null   object
#  9   Ratings              1044 non-null   float64
#  10  Number_of_Ratings    1044 non-null   object
#  11  Size_and_Dimensions  1098 non-null   object
#  12  Available_Colors     453 non-null    object
#  13  Product_Details      1253 non-null   object
#  14  Fit_and_Size         1149 non-null   object
# ...

# %%
#Describe the data
df.describe()
# Out:
#            Ratings
# count  1044.000000
# mean      4.159962
# std       0.346668
# min       2.100000
# 25%       4.000000
# 50%       4.200000
# 75%       4.400000
# max       5.000000

# %%
df.iloc[:1]
# Out:
#    Gender      Category Sub-Category Site_Name  \
# 0  Female  Western Wear      Dresses    Myntra
#
#                                          Product_URL Brand_Name  \
# 0  https://www.myntra.com/dresses/antheaa/antheaa...    Antheaa
#
#                                       Product_name Price  \
# 0  Fuchsia Solid Chiffon Smocked Tiered Midi Dress  1007
#
#                                           Image_URLs  Ratings  ...  \
# 0  https://assets.myntassets.com/h_720,q_90,w_540...      4.2  ...
#
#   Size_and_Dimensions Available_Colors  \
# 0                 NaN              NaN
#
#                                      Product_Details  \
# 0  Fuchsia solid fit & flare dress | Square neck ...
#
#                                  Fit_and_Size      Material_and_Care  \
# 0  The model (height 5'8) is wearing a size S  Polyester | Hand Wash
#
#                                       Specifications  \
# 0  Shape : Fit and Flare | Neck : Square Neck | L...
#
# ...

# %%
#Find the duplicates
df.duplicated().sum()
# Out:
# 3

# %%
#unique values
df['Category'].unique()
# Out:
# array(['Western Wear'], dtype=object)

# %%
df['Sub-Category'].unique()
# Out:
# array(['Dresses'], dtype=object)

# %%
#Find null values
df.isnull().sum()
# Out:
# Gender                   0
# Category                 0
# Sub-Category             0
# Site_Name                0
# Product_URL              0
# Brand_Name               0
# Product_name             0
# Price                    0
# Image_URLs               0
# Ratings                209
# Number_of_Ratings      209
# Size_and_Dimensions    155
# Available_Colors       800
# Product_Details          0
# Fit_and_Size           104
# Material_and_Care        2
# Specifications           9
# Fit                    334
# Length                 334
# Transparency           334
# Customer_Images        658
# dtype: int64

# %%
#Datatypes

df.dtypes
# Out:
# Gender                  object
# Category                object
# Sub-Category            object
# Site_Name               object
# Product_URL             object
# Brand_Name              object
# Product_name            object
# Price                   object
# Image_URLs              object
# Ratings                float64
# Number_of_Ratings       object
# Size_and_Dimensions     object
# Available_Colors        object
# Product_Details         object
# Fit_and_Size            object
# Material_and_Care       object
# Specifications          object
# Fit                     object
# Length                  object
# Transparency            object
# Customer_Images         object
# dtype: object

# %%
#Filter data
df[df['Site_Name']==1].head()
# Out:
# Empty DataFrame
# Columns: [Gender, Category, Sub-Category, Site_Name, Product_URL, Brand_Name, Product_name, Price, Image_URLs, Ratings, Number_of_Ratings, Size_and_Dimensions, Available_Colors, Product_Details, Fit_and_Size, Material_and_Care, Specifications, Fit, Length, Transparency, Customer_Images]
# Index: []
#
# [0 rows x 21 columns]

# %%
df['Product_URL'].value_counts()
# Out:
# https://www.myntra.com/dresses/dressberry/dressberry-women-solid-dress/21114132/buy                                                      2
# https://www.myntra.com/dresses/street-9/street-9-women-black-embellished-maxi-dress/13904688/buy                                         2
# https://www.myntra.com/dresses/ketch/ketch-checked-pinafore-mini-dress-with-t-shirt/21234828/buy                                         2
# https://www.myntra.com/dresses/tokyo-talkies/tokyo-talkies-black-floral-crepe-a-line-dress/16099806/buy                                  2
# https://www.myntra.com/dresses/antheaa/antheaa-fuchsia-solid-chiffon-smocked-tiered-midi-dress/15577328/buy                              1
#                                                                                                                                         ..
# https://www.myntra.com/dresses/indibelle/indibelle-burgundy--orange-floral-puff-sleeves-midi-dress/18135174/buy                          1
# ...

# %%
brand_name = df.Brand_Name.value_counts().index

# %%
Brand_value = df.Brand_Name.value_counts().values

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (10, 30)
plt.pie(Brand_value[:20],labels = brand_name[:20],autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7fd6377aceb0>,
# ...
#  [Text(0.9701133907831906, 0.5185364105085974, 'Tokyo Talkies'),
#   Text(0.20236463473517052, 1.0812254874023741, 'Stylecast X Hersheinbox'),
#   Text(-0.5655130186125439, 0.9435014710002994, 'Athena'),
#   Text(-1.0047873521455053, 0.44766324058205226, 'SASSAFRAS'),
#   Text(-1.0874769510442486, -0.1655109692664057, 'Berrylush'),
#   Text(-0.8529404073413492, -0.6946169171020624, 'plusS'),
#   Text(-0.518536399155026, -0.9701133968518009, 'MANGO'),
#   Text(-0.2268065365438117, -1.076363690850356, 'Antheaa'),
#   Text(0.058122594939276635, -1.0984633648681803, 'DressBerry'),
#   Text(0.2993839409147616, -1.0584749670740194, 'STREET 9'),
#   Text(0.50012958461079, -0.9797297579419739, 'DODO & MOA'),
#   Text(0.6586007242190917, -0.8810477206474621, 'Darzi'),
#   Text(0.771921340922951, -0.783669218119299, 'HERE&NOW'),
#   Text(0.8607540542932466, -0.6849105474569208, 'Frempy'),
# ...

# %%
df[['Tight', 'A Little Tight','Just Right','A Little Loose','Loose']] = df["Fit"].apply(lambda x: pd.Series(str(x).split(",")))
print(df)
